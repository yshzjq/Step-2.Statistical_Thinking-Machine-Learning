# %% [markdown]
# <a href="https://colab.research.google.com/github/yshzjq/Step-2.Statistical_Thinking-Machine-Learning/blob/main/Step%202.%20%ED%86%B5%EA%B3%84%EC%A0%81%20%EC%82%AC%EA%B3%A0%EC%99%80%20%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D%20%EC%9E%85%EB%AC%B8/2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 데이터 처리를 위한 라이브러리
import pandas as pd
import numpy as np

# 시각화 라이브러리
import matplotlib.pyplot as plt
import seaborn as sns

# 머신러닝 라이브러리 (sklearn)
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
# 아이리스 데이터셋 로드
iris = load_iris()

# 입력 데이터 (특징)
X = iris.data

# 정답 데이터 (라벨)
y = iris.target

# 컬럼명 가져오기
feature_names = iris.feature_names

# 데이터프레임으로 변환
df = pd.DataFrame(X, columns=feature_names)

# 정답 컬럼 추가
df['target'] = y

df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# 학습 데이터와 테스트 데이터 분리 (8:2)
X_train, X_test, y_train, y_test = train_test_split(
    X,# 입력 데이터
    y,# 정답 데이터
    test_size=0.2,# 테스트 비율
    random_state=42# 결과 고정용
)

# %%
# 랜덤포레스트 분류 모델 생성
model = RandomForestClassifier(
    random_state=42
)

# %%
# 모델 학습
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# 테스트 데이터로 예측
y_pred = model.predict(X_test)

y_pred[:5]
# Out:
# array([1, 0, 2, 1, 1])

# %%
# 실제 정답과 예측 결과 비교
result_df = pd.DataFrame({
'실제값': y_test,
'예측값': y_pred
})

result_df.head()
# Out:
#    실제값  예측값
# 0    1    1
# 1    0    0
# 2    2    2
# 3    1    1
# 4    1    1
